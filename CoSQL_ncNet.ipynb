# %%
from ncNet import ncNet
from vega import VegaLite
import requests
import pandasql as ps
import pandas as pd

# %%
ncNet = ncNet(
    trained_model= './save_models/trained_model.pt'
)
# Out:
# /Users/rajatjalal/opt/anaconda3/envs/ncnet/lib/python3.8/site-packages/torchtext/data/field.py:150: UserWarning: Field class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)
# /Users/rajatjalal/opt/anaconda3/envs/ncnet/lib/python3.8/site-packages/torchtext/data/example.py:68: UserWarning: Example class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('Example class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.', UserWarning)
# ...

# %%
district = pd.read_csv("/Users/rajatjalal/Documents/ECS_289H/Project/CoSQL/picard/database/district/district.csv")
us_counties = pd.read_csv("/Users/rajatjalal/Documents/ECS_289H/Project/CoSQL/picard/database/us_counties/us_counties.csv")

# %%
tableName = "district"

nlQuery = "show me all the district, active, deceased in the Bihar"
#nlQuery = "show me all the total active, deceased  in each state"

#nlQuery = "show me all dates, cases and deaths in Los Angeles"
#nlQuery = "show me top 5 data with most deaths on 2020-05-01"

URL = "http://localhost:8000/ask/"+tableName+"/"+nlQuery
r = requests.get(url = URL)
print(r.json()['query'])
# Out:
# select district, active, deceased from district where state = 'Bihar'

# %%
output=ps.sqldf(r.json()['query'], locals())
print(output)
# Out:
#           District  Active  Deceased
# 0           Araria     413         7
# 1            Arwal     216         3
# 2       Aurangabad     448         5
# 3            Banka     358         3
# 4        Begusarai     812        11
# 5        Bhagalpur     789        33
# 6          Bhojpur     666        14
# 7            Buxar     593         4
# 8        Darbhanga     414        10
# 9   East Champaran     712        13
# 10            Gaya     852        26
# 11       Gopalganj     390         1
# 12           Jamui     328         5
# 13       Jehanabad     362         6
# 14          Kaimur     161         7
# 15         Katihar     948         3
# 16        Khagaria     489         6
# 17      Kishanganj     276         4
# 18      Lakhisarai     186         4
# 19       Madhepura     328         4
# 20       Madhubani     663         2
# 21          Munger     384        18
# 22     Muzaffarpur     892        15
# 23         Nalanda     978        20
# ...

# %%
ncNet.specify_dataset(
    data_type='csv',
    data=output,
    table_name=tableName
)

# %%
ncNet.show_dataset(top_rows=3)
# Out:
#          date   states      cases  number
# 0  2020-04-12  Alabama  confirmed  3667.0
# 1  2020-04-12  Alabama     deaths    93.0
# 2  2020-04-12  Alabama  recovered     NaN

# %%
ncNet.nl2vis(
    nl_question='show me the trend about mean active cases as bar chart',
    #nl_question='show me the trend about mean deceased case per state as bar chart',

    #nl_question='what is the average cases and date for each date. Plot them as line chart',
    #nl_question='show me the mean cases for each county in a pie chart',
    show_progress = False
)[0]
# Out:
# /Users/rajatjalal/opt/anaconda3/envs/ncnet/lib/python3.8/site-packages/py_stringsimjoin/utils/generic_helper.py:76: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   projected_dataframe = dataframe[proj_attrs].dropna(0,
# /Users/rajatjalal/opt/anaconda3/envs/ncnet/lib/python3.8/site-packages/py_stringsimjoin/utils/generic_helper.py:76: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   projected_dataframe = dataframe[proj_attrs].dropna(0,
# /Users/rajatjalal/opt/anaconda3/envs/ncnet/lib/python3.8/site-packages/py_stringsimjoin/utils/generic_helper.py:76: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   projected_dataframe = dataframe[proj_attrs].dropna(0,
# ...

# %%
ncNet.nl2vis(
    nl_question='how many cars by year',
    chart_template=None
)[0] # nl2vis will return a list a [Vis, VegaLiteSpec]
# Out:
# <n> how many cars by year </n> <c> mark [t] data [d] encoding x [x] y aggregate [aggfunction] [y] color [z] transform filter [f] group [g] bin [b] sort [s] topk [k] </c> <d> cars_data <col> year </col> <val>  </val> </d>
# [NL Question]: how many cars by year
# [Chart Template]: None
# [Predicted VIS Query]: mark line data cars_data encoding x year y aggregate count year transform group x
